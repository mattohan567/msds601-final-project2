# %% [markdown]
# # Selecting a Model

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import re
import pickle
from itertools import combinations

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv('../data/cleaned_car_price_prediction.csv')
df['HasTurbo'] = df['HasTurbo'].astype(int)
df.columns = [re.sub(' ', '_', col) for col in df.columns]
df.columns = [re.sub('\.', '', col) for col in df.columns]
x_cols = df.columns[1:]
df = df.sample(n=2000, random_state=42)
df.head()
# Out:
#        Price   Manufacturer  Prod_year   Category Leather_interior  \
# 736    27284      CHEVROLET       2014  Hatchback               No
# 8674   10349  MERCEDES-BENZ       1997   Microbus              Yes
# 5971   40769  MERCEDES-BENZ       1996      Sedan               No
# 1957   38737        HYUNDAI       2014       Jeep              Yes
# 11075  42102      SSANGYONG       2017       Jeep              Yes
#
#             Fuel_type  Engine_Volume  HasTurbo  Mileage  Cylinders  \
# 736    Plug-in Hybrid            1.4         0    65000        4.0
# 8674           Diesel            2.9         1     3333        6.0
# 5971           Petrol            1.8         0   212485        8.0
# 1957           Diesel            2.0         0   132756        4.0
# 11075          Petrol            1.6         0    50750        4.0
#
#       Gear_box_type Drive_wheels   Doors       Wheel   Color  Airbags
# 736       Automatic        Front  04-May  Left wheel  Silver       10
# 8674         Manual         Rear  02-Mar  Left wheel     Red        2
# 5971         Manual         Rear  04-May  Left wheel   Green        2
# 1957      Automatic        Front  04-May  Left wheel    Grey        4
# 11075     Automatic        Front  04-May  Left wheel   White        4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 736 to 15704
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             2000 non-null   int64
#  1   Manufacturer      2000 non-null   object
#  2   Prod_year         2000 non-null   int64
#  3   Category          2000 non-null   object
#  4   Leather_interior  2000 non-null   object
#  5   Fuel_type         2000 non-null   object
#  6   Engine_Volume     2000 non-null   float64
#  7   HasTurbo          2000 non-null   int64
#  8   Mileage           2000 non-null   int64
#  9   Cylinders         2000 non-null   float64
#  10  Gear_box_type     2000 non-null   object
#  11  Drive_wheels      2000 non-null   object
#  12  Doors             2000 non-null   object
#  13  Wheel             2000 non-null   object
#  14  Color             2000 non-null   object
#  15  Airbags           2000 non-null   int64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 265.6+ KB

# %% [markdown]
# ## Funtion Creation

# %%
def all_subsets(lst):
    subsets = []
    # Iterate over all possible lengths of the subset
    for r in range(len(lst) + 1):
        # Generate all combinations of length r
        for combo in combinations(lst, r):
            subsets.append(list(combo))
    return subsets

# %%
subsets = all_subsets(x_cols) #list of all predictors
subsets = subsets[1:]
len(subsets)
# Out:
# 32767

# %%
n = 100
sections = []
for i in range(n):
    k = len(subsets) // n 
    if i == n - 1:
        sections += [subsets[i*k:]]
    else: 
        sections += [subsets[i*k:i*k+k]]
sum([len(section) for section in sections])
subsets[327:327+10] == sections[1][:10]
# Out:
# 32767

# %%
subsets[327:327+10] == sections[1][:10]
# Out:
# True

# %%
def calculate_metrics(model, X, y):
    n = len(y)
    k = model.df_model  # Number of predictors, excluding intercept
    
    # AIC
    aic = model.aic
    
    # BIC
    bic = model.bic
    
    # PRESS (Prediction Sum of Squares)
    hat_matrix = X @ np.array(np.linalg.inv(X.T @ X) @ X.T)
    residuals = model.resid
    press = np.sum((residuals)**2 / (1 - np.diag(hat_matrix)))
        
    # Adjusted R-squared
    r2 = model.rsquared
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Mean Squared Error MSE
    residuals = model.resid
    mse = (residuals ** 2).mean()
    
    return aic, bic, press, adj_r2, int(k), mse #dont consider intercept as a predictor

# %%
def cross_validate(X, y, k=5):
    np.random.seed(42)  # For reproducibility
    shuffled_indices = np.random.permutation(len(X))
    fold_sizes = len(X) // k
    scores = []
    for i in range(k):
        val_start = i * fold_sizes
        val_end = val_start + fold_sizes
        val_indices = shuffled_indices[val_start:val_end]
        train_indices = np.concatenate([shuffled_indices[:val_start], shuffled_indices[val_end:]])
        # print(val_indices, train_indices)

        X_train, y_train = X.iloc[train_indices], y.iloc[train_indices]
        X_val, y_val = X.iloc[val_indices], y.iloc[val_indices]
        
        #calculate mse if you train the model with the training set
        model = sm.OLS(y_train, X_train).fit()
        predictions = model.predict(X_val)
        mse = ((predictions - y_val.squeeze()) ** 2).mean()
        scores.append(mse)

    return sum(scores) / len(scores)

# %%
n = 100
sections = []
for i in range(n):
    k = len(subsets) // n 
    if i == n - 1:
        sections += [subsets[i*k:]]
    else: 
        sections += [subsets[i*k:i*k+k]]
len(sections[0])

def results_to_pkl(subsets, index):     
    results = []
    for j, predictors in enumerate(subsets):
        # if j == 7: break
        # print(predictors)
        formula = "Price ~ " #initiate the formula
        for i, predictor in enumerate(predictors):
            if i == 0:
                if df.dtypes[predictor] == 'object':
                    formula += f'C({predictor})'
                else:
                    formula += predictor
            else:
                if df.dtypes[predictor] == 'object':
                    formula += f' + C({predictor})'
                else:
                    formula += f' + {predictor}'
                    
        #train the model            
        model = smf.ols(formula, data = df).fit()
        
        y = df['Price']
        X = df[predictors].copy()
        cat_cols = []
        for predictor in predictors: 
            if X.dtypes[predictor] == 'object':
                cat_cols.append(predictor)
        if len(cat_cols) > 0:
            X = pd.get_dummies(X, columns=cat_cols, drop_first=True)
            for col in X.columns:
                X[col] = X[col].astype(float)
        X = sm.add_constant(X, has_constant='add')
                
        aic, bic, press, adj_r2, num_predictors, mse = calculate_metrics(model, X = X, y = y)
        mse_cv_5 = cross_validate(X, y, k = 5)
        mse_cv_10 = cross_validate(X, y, k = 10)
        mse_cv_100 = cross_validate(X, y, k = 100)
        
        results.append({
            'Predictors': predictors,
            'n_Predictors': num_predictors,
            'Adjusted R^2': adj_r2,
            'AIC': aic,
            'BIC': bic,
            'PRESS': press,
            'MSE': mse,
            '5-Fold_CV MSE': mse_cv_5,
            '10-Fold_CV MSE': mse_cv_10,
            '100-Fold_CV MSE': mse_cv_100        
        })
            
    # Convert results to pd DataFrame
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values(by='n_Predictors').reset_index(drop=True)
    with open(f'models/results_df_{index}', 'wb') as f:
        pickle.dump(results_df, f)

# %%
results_to_pkl(sections[0], 0)

# %%
with open(f'models/results_df_6', 'rb') as f:
    data = pickle.load(f)
# with open(f'models/results_df', 'rb') as f:
#     data = pickle.load(f)
data
# Out:
#                                Predictors  n_Predictors  Adjusted R^2  \
# 0                                 [Wheel]             1      0.017918
# 1                             [Prod_year]             1      0.086412
# 2                      [Leather_interior]             1      0.017062
# 3                         [Engine_Volume]             1      0.011778
# 4                              [HasTurbo]             1      0.047422
# ..                                    ...           ...           ...
# 322   [Manufacturer, Drive_wheels, Color]            62      0.094518
# 323          [Manufacturer, Doors, Color]            62      0.091023
# 324  [Manufacturer, Gear_box_type, Color]            63      0.129996
# 325      [Manufacturer, Fuel_type, Color]            65      0.126240
# 326       [Manufacturer, Category, Color]            69      0.122239
#
#               AIC           BIC         PRESS           MSE  5-Fold_CV MSE  \
# 0    44932.145767  44943.347572  6.680732e+11  3.338478e+08   3.341604e+08
# 1    44787.554836  44798.756641  6.221476e+11  3.105639e+08   3.110198e+08
# 2    44933.888300  44945.090105  6.688104e+11  3.341388e+08   3.347360e+08
# 3    44944.611106  44955.812911  6.730064e+11  3.359351e+08   3.367175e+08
# 4    44871.139192  44882.340997  6.485958e+11  3.238181e+08   3.242530e+08
# ..            ...           ...           ...           ...            ...
# 322  44829.750042  45182.606897           inf  2.984157e+08   3.137097e+08
# 323  44837.453530  45190.310385           inf  2.995673e+08   3.143558e+08
# 324  44750.777002  45109.234759  5.848569e+11  2.865752e+08   3.010295e+08
# 325  44761.326724  45130.986286  5.872067e+11  2.875152e+08   3.034995e+08
# 326  44774.325571  45166.388743           inf  2.882347e+08   3.078572e+08
#
#      10-Fold_CV MSE  100-Fold_CV MSE
# 0      3.340392e+08     3.341389e+08
# 1      3.112046e+08     3.113505e+08
# 2      3.345047e+08     3.345622e+08
# 3      3.366080e+08     3.368707e+08
# 4      3.242776e+08     3.246379e+08
# ..              ...              ...
# 322    3.125216e+08     3.135079e+08
# 323    3.134102e+08     3.143261e+08
# 324    2.998683e+08     3.006153e+08
# 325    3.021386e+08     3.024989e+08
# 326    3.056342e+08     3.058383e+08
#
# [327 rows x 10 columns]

# %%
for i in range(n):
    results_to_pkl(sections[i], i)

# %%
dataframes = []
for i in range(n):
    with open(f'models/results_df_{i}', 'rb') as f:
        data = pickle.load(f)
    #concat all the data into one dataframe
    dataframes.append(data)
results_df = pd.DataFrame(dataframes)
with open(f'models/full_results_df', 'wb') as f:
        pickle.dump(results_df, f)

# %%
# results = []
# for j, predictors in enumerate(subsets):
#     # if j == 7: break
#     # print(predictors)
#     formula = "Price ~ " #initiate the formula
#     for i, predictor in enumerate(predictors):
#         if i == 0:
#             if df.dtypes[predictor] == 'object':
#                 formula += f'C({predictor})'
#             else:
#                 formula += predictor
#         else:
#             if df.dtypes[predictor] == 'object':
#                 formula += f' + C({predictor})'
#             else:
#                 formula += f' + {predictor}'
                
#     #train the model            
#     model = smf.ols(formula, data = df).fit()
    
#     y = df['Price']
#     X = df[predictors].copy()
#     cat_cols = []
#     for predictor in predictors: 
#         if X.dtypes[predictor] == 'object':
#             cat_cols.append(predictor)
#     if len(cat_cols) > 0:
#         X = pd.get_dummies(X, columns=cat_cols, drop_first=True)
#         for col in X.columns:
#             X[col] = X[col].astype(float)
#     X = sm.add_constant(X, has_constant='add')
            
#     aic, bic, press, adj_r2, num_predictors, mse = calculate_metrics(model, X = X, y = y)
#     mse_cv_5 = cross_validate(X, y, k = 5)
#     mse_cv_10 = cross_validate(X, y, k = 10)
#     mse_cv_100 = cross_validate(X, y, k = 100)
    
#     results.append({
#         'Predictors': predictors,
#         'n_Predictors': num_predictors,
#         'Adjusted R^2': adj_r2,
#         'AIC': aic,
#         'BIC': bic,
#         'PRESS': press,
#         'MSE': mse,
#         '5-Fold_CV MSE': mse_cv_5,
#         '10-Fold_CV MSE': mse_cv_10,
#         '100-Fold_CV MSE': mse_cv_100        
#     })
        
# # Convert results to pd DataFrame
# results_df = pd.DataFrame(results)
# results_df = results_df.sort_values(by='n_Predictors').reset_index(drop=True)
# with open(f'models/results_df', 'wb') as f:
#     pickle.dump(results_df, f)

# %%
with open(f'models/results_df_1', 'rb') as f:
    results_df = pickle.load(f)
results_df
# Out:
#            Predictors  n_Predictors  Adjusted R^2            AIC  \
# 0         [Prod_year]             1  1.685437e-04  522352.503679
# 1  [Leather_interior]             1  5.688586e-07  522355.735284
# 2     [Engine_Volume]             1  7.660652e-05  522354.272491
# 3          [HasTurbo]             1  3.020182e-04  522349.935427
# 4         [Fuel_type]             6  1.016721e-03  522341.176698
# 5          [Category]            10  3.858554e-03  522290.373084
# 6      [Manufacturer]            64  3.639341e-04  522411.637281
#
#              BIC         PRESS           MSE  5-Fold_CV MSE  10-Fold_CV MSE  \
# 0  522368.232861  6.987529e+14  3.631321e+10   3.633892e+10    3.634755e+10
# 1  522371.464466  6.988061e+14  3.631931e+10   3.633896e+10    3.634687e+10
# 2  522370.001673  6.986763e+14  3.631655e+10   3.632689e+10    3.633641e+10
# 3  522365.664609  6.985053e+14  3.630836e+10   3.631717e+10    3.632617e+10
# 4  522396.228834           inf  3.627297e+10   3.629670e+10    3.630429e+10
# 5  522376.883582  6.986275e+14  3.616226e+10   3.650585e+10    3.649847e+10
# 6  522922.835682           inf  3.618721e+10   3.643697e+10    3.643281e+10
#
#    100-Fold_CV MSE
# 0     3.640339e+10
# 1     3.640256e+10
# 2     3.639196e+10
# 3     3.638222e+10
# 4     3.636056e+10
# 5     3.654383e+10
# 6     3.648061e+10

# %% [markdown]
# # Analysis

# %%
print('Lowest MSE')
results_df.loc[results_df['MSE'].idxmin()]
# Out:
# Lowest MSE
# Predictors                 [Category]
# n_Predictors                       10
# Adjusted R^2                 0.003859
# AIC                     522290.373084
# BIC                     522376.883582
# PRESS              698627511100193.25
# MSE                36162264914.094215
# 5-Fold_CV MSE      36505852407.023056
# 10-Fold_CV MSE     36498472658.730316
# 100-Fold_CV MSE    36543825293.901321
# Name: 5, dtype: object

# %%
print('Lowest CV MSE')
results_df.loc[results_df['5-Fold_CV MSE'].idxmin()]
# Out:
# Lowest CV MSE
# Predictors                [Fuel_type]
# n_Predictors                        6
# Adjusted R^2                 0.001017
# AIC                     522341.176698
# BIC                     522396.228834
# PRESS                             inf
# MSE                36272974759.054375
# 5-Fold_CV MSE      36296701410.087692
# 10-Fold_CV MSE     36304286846.241257
# 100-Fold_CV MSE    36360563173.718864
# Name: 4, dtype: object

# %%
print('Lowest AIC')
results_df.loc[results_df['AIC'].idxmin()]
# Out:
# Lowest AIC
# Predictors                 [Category]
# n_Predictors                       10
# Adjusted R^2                 0.003859
# AIC                     522290.373084
# BIC                     522376.883582
# PRESS              698627511100193.25
# MSE                36162264914.094215
# 5-Fold_CV MSE      36505852407.023056
# 10-Fold_CV MSE     36498472658.730316
# 100-Fold_CV MSE    36543825293.901321
# Name: 5, dtype: object

# %%
print('Lowest BIC')
results_df.loc[results_df['BIC'].idxmin()]
# Out:
# Lowest BIC
# Predictors                 [HasTurbo]
# n_Predictors                        1
# Adjusted R^2                 0.000302
# AIC                     522349.935427
# BIC                     522365.664609
# PRESS               698505251493110.5
# MSE                36308363165.083794
# 5-Fold_CV MSE      36317166325.836815
# 10-Fold_CV MSE     36326166742.250198
# 100-Fold_CV MSE    36382222399.537987
# Name: 3, dtype: object

# %%
print('Highest Adjusted R^2	')
results_df.loc[results_df['Adjusted R^2'].idxmax()]
# Out:
# Highest Adjusted R^2
# Predictors                 [Category]
# n_Predictors                       10
# Adjusted R^2                 0.003859
# AIC                     522290.373084
# BIC                     522376.883582
# PRESS              698627511100193.25
# MSE                36162264914.094215
# 5-Fold_CV MSE      36505852407.023056
# 10-Fold_CV MSE     36498472658.730316
# 100-Fold_CV MSE    36543825293.901321
# Name: 5, dtype: object
