# %% [markdown]
# # Selecting a Model

# %% [markdown]
# ## Import Necessary Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import re
import pickle
from itertools import combinations

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv('../data/cleaned_car_price_prediction_door_fix.csv')
df['HasTurbo'] = df['HasTurbo'].astype(int)
df.columns = [re.sub(' ', '_', col) for col in df.columns]
df.columns = [re.sub('\.', '', col) for col in df.columns]
x_cols = df.columns[1:]
df = df.sample(n=2000, random_state=42) # select a subset
df.head()
df.Doors.value_counts()
# Out:
# Doors
# 4     1913
# 2       81
# >5       6
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 736 to 15704
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             2000 non-null   int64
#  1   Manufacturer      2000 non-null   object
#  2   Prod_year         2000 non-null   int64
#  3   Category          2000 non-null   object
#  4   Leather_interior  2000 non-null   object
#  5   Fuel_type         2000 non-null   object
#  6   Engine_Volume     2000 non-null   float64
#  7   HasTurbo          2000 non-null   int64
#  8   Mileage           2000 non-null   int64
#  9   Cylinders         2000 non-null   float64
#  10  Gear_box_type     2000 non-null   object
#  11  Drive_wheels      2000 non-null   object
#  12  Doors             2000 non-null   object
#  13  Wheel             2000 non-null   object
#  14  Color             2000 non-null   object
#  15  Airbags           2000 non-null   int64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 265.6+ KB

# %% [markdown]
# ## Fitting full MLR model

# %%
formula = "Price ~ " #initiate the formula
for i, predictor in enumerate(x_cols):
    if i == 0:
        if df.dtypes[predictor] == 'object': 
            formula += f'C({predictor})'
        else:
            formula += predictor
    else:
        if df.dtypes[predictor] == 'object':
            formula += f' + C({predictor})'
        else:
            formula += f' + {predictor}'
full_model = smf.ols(formula, data = df).fit()
print(full_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     11.74
# Date:                Fri, 11 Oct 2024   Prob (F-statistic):          8.21e-125
# Time:                        15:28:23   Log-Likelihood:                -22046.
# No. Observations:                2000   AIC:                         4.427e+04
# Df Residuals:                    1910   BIC:                         4.478e+04
# Df Model:                          89
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                         -3.05e+06   1.92e+05    -15.907      0.000   -3.43e+06   -2.67e+06
# C(Manufacturer)[T.AUDI]           2754.3005   9379.543      0.294      0.769   -1.56e+04    2.11e+04
# C(Manufacturer)[T.BMW]             1.23e+04   9000.351      1.367      0.172   -5348.508       3e+04
# C(Manufacturer)[T.BUICK]          -592.2301   1.76e+04     -0.034      0.973   -3.52e+04     3.4e+04
# C(Manufacturer)[T.CADILLAC]       6681.6366   1.13e+04      0.594      0.553   -1.54e+04    2.88e+04
# C(Manufacturer)[T.CHEVROLET]      5559.4101   8967.952      0.620      0.535    -1.2e+04    2.31e+04
# C(Manufacturer)[T.CHRYSLER]       1.309e+04    1.4e+04      0.935      0.350   -1.44e+04    4.05e+04
# C(Manufacturer)[T.CITROEN]        6087.4271   1.26e+04      0.482      0.630   -1.87e+04    3.09e+04
# C(Manufacturer)[T.DAEWOO]         7776.5704   9893.797      0.786      0.432   -1.16e+04    2.72e+04
# C(Manufacturer)[T.DAIHATSU]        -79.0156   1.78e+04     -0.004      0.996    -3.5e+04    3.48e+04
# C(Manufacturer)[T.DODGE]          1904.7471   9779.185      0.195      0.846   -1.73e+04    2.11e+04
# C(Manufacturer)[T.FIAT]           4874.2643   1.26e+04      0.387      0.699   -1.99e+04    2.96e+04
# C(Manufacturer)[T.FORD]           1.258e+04   8955.264      1.405      0.160   -4980.755    3.01e+04
# C(Manufacturer)[T.GAZ]            1.285e+05   1.86e+04      6.907      0.000     9.2e+04    1.65e+05
# C(Manufacturer)[T.GMC]            4730.9303   1.76e+04      0.268      0.789   -2.99e+04    3.93e+04
# C(Manufacturer)[T.HONDA]          1.069e+04   8986.367      1.190      0.234   -6931.064    2.83e+04
# C(Manufacturer)[T.HUMMER]        -1170.9537   1.41e+04     -0.083      0.934   -2.88e+04    2.64e+04
# C(Manufacturer)[T.HYUNDAI]        1.469e+04   8885.973      1.653      0.098   -2738.508    3.21e+04
# C(Manufacturer)[T.INFINITI]       1.175e+04   1.25e+04      0.940      0.347   -1.28e+04    3.63e+04
# C(Manufacturer)[T.JAGUAR]        -4122.6182   1.26e+04     -0.328      0.743   -2.88e+04    2.05e+04
# C(Manufacturer)[T.JEEP]            1.14e+04   9501.093      1.199      0.230   -7237.205       3e+04
# C(Manufacturer)[T.KIA]            6093.2642   9100.802      0.670      0.503   -1.18e+04    2.39e+04
# C(Manufacturer)[T.LANCIA]         1.224e+04   1.78e+04      0.688      0.492   -2.26e+04    4.71e+04
# C(Manufacturer)[T.LAND ROVER]     3.297e+04   1.04e+04      3.157      0.002    1.25e+04    5.35e+04
# C(Manufacturer)[T.LEXUS]          7748.3447   8964.455      0.864      0.388   -9832.805    2.53e+04
# C(Manufacturer)[T.LINCOLN]        1.609e+04   1.78e+04      0.902      0.367   -1.89e+04    5.11e+04
# C(Manufacturer)[T.MAZDA]          7579.9549   9490.040      0.799      0.425    -1.1e+04    2.62e+04
# C(Manufacturer)[T.MERCEDES-BENZ]  1.422e+04   8935.739      1.591      0.112   -3306.556    3.17e+04
# C(Manufacturer)[T.MINI]           1.226e+04   1.08e+04      1.131      0.258   -8991.290    3.35e+04
# C(Manufacturer)[T.MITSUBISHI]     1.175e+04   9280.967      1.266      0.206   -6454.001    2.99e+04
# C(Manufacturer)[T.NISSAN]         2632.8552   9033.194      0.291      0.771   -1.51e+04    2.03e+04
# C(Manufacturer)[T.OPEL]           1.383e+04   9221.933      1.499      0.134   -4259.891    3.19e+04
# C(Manufacturer)[T.PEUGEOT]        5749.5006   1.78e+04      0.323      0.747   -2.91e+04    4.06e+04
# C(Manufacturer)[T.PORSCHE]         3.02e+04   1.06e+04      2.858      0.004    9474.236    5.09e+04
# C(Manufacturer)[T.RENAULT]       -6695.0441   1.26e+04     -0.530      0.596   -3.15e+04    1.81e+04
# C(Manufacturer)[T.SAAB]          -4824.5968   1.77e+04     -0.272      0.786   -3.96e+04       3e+04
# C(Manufacturer)[T.SCION]          9644.5953   1.81e+04      0.534      0.594   -2.58e+04    4.51e+04
# C(Manufacturer)[T.SKODA]          1.216e+04   1.17e+04      1.036      0.301   -1.09e+04    3.52e+04
# C(Manufacturer)[T.SSANGYONG]      1.714e+04   9195.731      1.863      0.063    -899.617    3.52e+04
# C(Manufacturer)[T.SUBARU]         4258.1713   9270.419      0.459      0.646   -1.39e+04    2.24e+04
# C(Manufacturer)[T.SUZUKI]         1.302e+04   1.04e+04      1.250      0.211   -7399.499    3.34e+04
# C(Manufacturer)[T.TOYOTA]         1.415e+04   8865.138      1.596      0.111   -3240.482    3.15e+04
# C(Manufacturer)[T.UAZ]            2.147e+04   1.26e+04      1.699      0.089   -3305.991    4.62e+04
# C(Manufacturer)[T.VAZ]            2.386e+04   1.11e+04      2.158      0.031    2174.654    4.55e+04
# C(Manufacturer)[T.VOLKSWAGEN]     6591.2688   9063.398      0.727      0.467   -1.12e+04    2.44e+04
# C(Manufacturer)[T.VOLVO]           648.0972    1.4e+04      0.046      0.963   -2.67e+04     2.8e+04
# C(Category)[T.Coupe]             -1.192e+04   9192.346     -1.297      0.195      -3e+04    6105.048
# C(Category)[T.Goods wagon]        -1.44e+04   9807.724     -1.468      0.142   -3.36e+04    4839.357
# C(Category)[T.Hatchback]         -8566.7703   9153.019     -0.936      0.349   -2.65e+04    9384.192
# C(Category)[T.Jeep]              -3945.3356   9131.668     -0.432      0.666   -2.19e+04     1.4e+04
# C(Category)[T.Microbus]          -8602.9618   9607.319     -0.895      0.371   -2.74e+04    1.02e+04
# C(Category)[T.Minivan]           -6675.0460   9278.785     -0.719      0.472   -2.49e+04    1.15e+04
# C(Category)[T.Pickup]            -3338.8987   1.15e+04     -0.290      0.772   -2.59e+04    1.93e+04
# C(Category)[T.Sedan]             -1.046e+04   9086.711     -1.152      0.250   -2.83e+04    7356.092
# C(Category)[T.Universal]         -1745.7689   9395.186     -0.186      0.853   -2.02e+04    1.67e+04
# C(Leather_interior)[T.Yes]         -37.0889   1031.882     -0.036      0.971   -2060.822    1986.645
# C(Fuel_type)[T.Diesel]           -2727.8307   2543.308     -1.073      0.284   -7715.784    2260.123
# C(Fuel_type)[T.Hybrid]           -9835.6404   2656.612     -3.702      0.000    -1.5e+04   -4625.475
# C(Fuel_type)[T.LPG]              -8981.7166   2936.039     -3.059      0.002   -1.47e+04   -3223.537
# C(Fuel_type)[T.Petrol]           -4317.7620   2420.847     -1.784      0.075   -9065.543     430.019
# C(Fuel_type)[T.Plug-in Hybrid]    3717.9128   5500.336      0.676      0.499   -7069.384    1.45e+04
# C(Gear_box_type)[T.Manual]        6398.5899   1875.855      3.411      0.001    2719.651    1.01e+04
# C(Gear_box_type)[T.Tiptronic]     1.088e+04   1135.977      9.580      0.000    8654.469    1.31e+04
# C(Gear_box_type)[T.Variator]      7788.9409   1887.950      4.126      0.000    4086.281    1.15e+04
# C(Drive_wheels)[T.Front]          3573.0915   1428.882      2.501      0.012     770.759    6375.424
# C(Drive_wheels)[T.Rear]           2796.3712   1630.012      1.716      0.086    -400.419    5993.162
# C(Doors)[T.4]                    -1190.6079   2318.102     -0.514      0.608   -5736.886    3355.670
# C(Doors)[T.>5]                    2050.6208   6683.831      0.307      0.759   -1.11e+04    1.52e+04
# C(Wheel)[T.Right-hand drive]      -693.8971   1641.296     -0.423      0.673   -3912.818    2525.023
# C(Color)[T.Black]                 1234.3123   4007.771      0.308      0.758   -6625.755    9094.380
# C(Color)[T.Blue]                 -1346.4349   4129.192     -0.326      0.744   -9444.634    6751.764
# C(Color)[T.Brown]                  456.3894   5707.539      0.080      0.936   -1.07e+04    1.17e+04
# C(Color)[T.Carnelian red]         3702.6674   5155.934      0.718      0.473   -6409.185    1.38e+04
# C(Color)[T.Golden]                2621.9491   5689.713      0.461      0.645   -8536.754    1.38e+04
# C(Color)[T.Green]                  859.2170   4893.199      0.176      0.861   -8737.359    1.05e+04
# C(Color)[T.Grey]                  -552.3965   4076.603     -0.136      0.892   -8547.458    7442.665
# C(Color)[T.Orange]               -7576.4142   6233.426     -1.215      0.224   -1.98e+04    4648.623
# C(Color)[T.Pink]                   849.2064   8794.852      0.097      0.923   -1.64e+04    1.81e+04
# C(Color)[T.Purple]               -8694.4852   1.16e+04     -0.748      0.454   -3.15e+04    1.41e+04
# C(Color)[T.Red]                  -2352.5169   4381.154     -0.537      0.591   -1.09e+04    6239.832
# C(Color)[T.Silver]                -144.3877   4034.122     -0.036      0.971   -8056.135    7767.359
# C(Color)[T.Sky blue]              -150.4675   5501.235     -0.027      0.978   -1.09e+04    1.06e+04
# C(Color)[T.White]                 -302.0326   4020.691     -0.075      0.940   -8187.438    7583.373
# C(Color)[T.Yellow]               -1050.0591   5760.610     -0.182      0.855   -1.23e+04    1.02e+04
# Prod_year                         1521.5736     95.696     15.900      0.000    1333.893    1709.254
# Engine_Volume                     1555.3763    800.978      1.942      0.052     -15.506    3126.259
# HasTurbo                          9404.3096   1382.716      6.801      0.000    6692.517    1.21e+04
# Mileage                          -2.773e-06   1.55e-05     -0.179      0.858   -3.32e-05    2.77e-05
# Cylinders                         1336.2913    525.279      2.544      0.011     306.111    2366.471
# Airbags                           -887.9322    100.374     -8.846      0.000   -1084.787    -691.078
# ==============================================================================
# Omnibus:                     1848.245   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           193460.826
# Skew:                           3.952   Prob(JB):                         0.00
# Kurtosis:                      50.530   Cond. No.                     1.26e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Funtion Creations

# %% [markdown]
# ### Generate every combination of all subsets

# %%
def all_subsets(lst):
    subsets = []
    # Iterate over all possible lengths of the subset
    for r in range(len(lst) + 1):
        # Generate all combinations of length r
        for combo in combinations(lst, r):
            subsets.append(list(combo))
    return subsets

# %% [markdown]
# ### Calculate some metrics given a model, predictors, and response

# %%
#calculate some metrics given a model, predictors, and response
def calculate_metrics(model, X, y):
    n = len(y)
    k = model.df_model  # Number of predictors, excluding intercept
    
    # AIC
    aic = model.aic
    
    # BIC
    bic = model.bic
    
    # PRESS (Prediction Sum of Squares)
    hat_matrix = X @ np.array(np.linalg.inv(X.T @ X) @ X.T)
    residuals = model.resid
    press = np.sum((residuals / (1 - np.diag(hat_matrix)))**2)
        
    # Adjusted R-squared
    r2 = model.rsquared
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - k - 1)
    
    # Mean Squared Error MSE
    residuals = model.resid
    mse = (residuals ** 2).mean()
    
    return aic, bic, press, adj_r2, int(k), mse #dont consider intercept as a predictor

# %% [markdown]
# ### Perform Cross Validation and find the MSE

# %%
def cross_validate(X, y, k=5):
    np.random.seed(42)  # For reproducibility
    shuffled_indices = np.random.permutation(len(X))
    fold_sizes = len(X) // k
    scores = []
    for i in range(k):
        val_start = i * fold_sizes
        val_end = val_start + fold_sizes
        val_indices = shuffled_indices[val_start:val_end]
        train_indices = np.concatenate([shuffled_indices[:val_start], shuffled_indices[val_end:]])
        # print(val_indices, train_indices)

        X_train, y_train = X.iloc[train_indices], y.iloc[train_indices]
        X_val, y_val = X.iloc[val_indices], y.iloc[val_indices]
        
        #calculate mse if you train the model with the training set
        model = sm.OLS(y_train, X_train).fit()
        predictions = model.predict(X_val)
        mse = ((predictions - y_val.squeeze()) ** 2).mean()
        scores.append(mse)

    return sum(scores) / len(scores)

# %% [markdown]
# ### Calculate results and save to pickle file

# %%
def results_to_pkl(subsets, index = ''):     
    results = []
    for j, predictors in enumerate(subsets):
        # if j == 7: break
        # print(predictors)
        formula = "Price ~ " #initiate the formula
        for i, predictor in enumerate(predictors):
            if i == 0:
                if df.dtypes[predictor] == 'object':
                    formula += f'C({predictor})'
                else:
                    formula += predictor
            else:
                if df.dtypes[predictor] == 'object':
                    formula += f' + C({predictor})'
                else:
                    formula += f' + {predictor}'
                    
        #train the model            
        model = smf.ols(formula, data = df).fit()
        
        #set up X and y for calculate_metrics adn cross_validate 
        y = df['Price']
        X = df[predictors].copy()
        cat_cols = []
        for predictor in predictors: 
            if X.dtypes[predictor] == 'object':
                cat_cols.append(predictor)
        if len(cat_cols) > 0:
            X = pd.get_dummies(X, columns=cat_cols, drop_first=True)
            for col in X.columns:
                X[col] = X[col].astype(float)
        X = sm.add_constant(X, has_constant='add')
                
        aic, bic, press, adj_r2, num_predictors, mse = calculate_metrics(model, X = X, y = y)
        mse_cv_5 = cross_validate(X, y, k = 5)
        mse_cv_10 = cross_validate(X, y, k = 10)
        # mse_cv_100 = cross_validate(X, y, k = 100)
        
        results.append({
            'Predictors': predictors,
            'n_Predictors': num_predictors,
            'Adjusted R^2': adj_r2,
            'AIC': aic,
            'BIC': bic,
            'PRESS': press,
            'MSE': mse,
            '5-Fold_CV MSE': mse_cv_5,
            '10-Fold_CV MSE': mse_cv_10,
            # '100-Fold_CV MSE': mse_cv_100        
        })
            
    # Convert results to pd DataFrame
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values(by='n_Predictors').reset_index(drop=True)
    with open(f'models/results_df_{index}.pkl', 'wb') as f:
        pickle.dump(results_df, f)

# %% [markdown]
# ## Testing Functions on Full Model

# %%
results_to_pkl([x_cols], index = 'full_model')
with open(f'models/results_df_full_model.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
#                                           Predictors  n_Predictors  \
# 0  Index(['Manufacturer', 'Prod_year', 'Category'...            89
#
#    Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 0      0.323434  44271.767731  44775.848952  1.177482e+24  2.197513e+08
#
#    5-Fold_CV MSE  10-Fold_CV MSE
# 0   1.585317e+10    1.662179e+10

# %% [markdown]
# ## Finding the Best Subset

# %% [markdown]
# ### Creating all subsets and sectioning them off

# %%
subsets = all_subsets(x_cols) #list of all predictors
subsets = subsets[1:]
len(subsets)
# Out:
# 32767

# %%
n = 100
k = len(subsets) // n 
sections = []
for i in range(n):
    if i == n - 1:
        sections += [subsets[i*k:]]
    else: 
        sections += [subsets[i*k:i*k+k]]
sum([len(section) for section in sections])
subsets[k:k+10] == sections[1][:10]
# Out:
# True

# %% [markdown]
# ### Testing on the random index

# %%
results_to_pkl(sections[47], 47)

# %%
with open(f'models/results_df_47.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
#                                             Predictors  n_Predictors  \
# 0    [Leather_interior, Fuel_type, Engine_Volume, M...            11
# 1    [Leather_interior, Fuel_type, Engine_Volume, H...            11
# 2    [Leather_interior, Fuel_type, Engine_Volume, H...            11
# 3    [Leather_interior, Fuel_type, Engine_Volume, H...            11
# 4    [Leather_interior, Fuel_type, Engine_Volume, H...            11
# ..                                                 ...           ...
# 322  [Category, Fuel_type, Cylinders, Gear_box_type...            35
# 323  [Category, Fuel_type, Gear_box_type, Doors, Wh...            36
# 324  [Category, Fuel_type, Gear_box_type, Drive_whe...            36
# 325  [Category, Fuel_type, Gear_box_type, Drive_whe...            37
# 326  [Category, Fuel_type, Gear_box_type, Drive_whe...            37
#
#      Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 0        0.086021  44797.374243  44864.585073  9.560712e+13  3.089871e+08
# 1        0.119269  44723.263596  44790.474425  1.050376e+14  2.977470e+08
# 2        0.111727  44740.317467  44807.528296  9.279032e+13  3.002967e+08
# 3        0.114739  44733.525466  44800.736296  1.070141e+14  2.992787e+08
# 4        0.119451  44722.849979  44790.060809  6.032950e+11  2.976854e+08
# ..            ...           ...           ...           ...           ...
# 322      0.159527  44653.397492  44855.029981  5.785253e+11  2.807069e+08
# 323      0.158424  44657.002023  44864.235414  5.782512e+11  2.809322e+08
# 324      0.162862  44646.427894  44853.661285  5.758543e+11  2.794508e+08
# 325      0.148632  44681.119760  44893.954054  5.861262e+11  2.840562e+08
# 326      0.155720  44664.397958  44877.232251  5.802847e+11  2.816912e+08
#
#      5-Fold_CV MSE  10-Fold_CV MSE
# 0     3.902114e+10    4.370982e+10
# 1     4.015779e+10    4.533714e+10
# 2     3.482777e+10    4.007582e+10
# 3     4.103108e+10    4.596733e+10
# 4     3.008719e+08    3.011131e+08
# ..             ...             ...
# 322   2.892778e+08    2.898945e+08
# 323   2.893221e+08    2.900816e+08
# 324   2.878597e+08    2.884234e+08
# 325   2.938311e+08    2.940034e+08
# 326   2.903605e+08    2.907272e+08
#
# [327 rows x 9 columns]

# %% [markdown]
# ### Finding the results for all the subsets

# %%
for i in range(n):
    results_to_pkl(sections[i], i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 for i in range(n):
# ----> 2     results_to_pkl(sections[i], i)
#
# Cell In[22], line 37, in results_to_pkl(subsets, index)
#      35 aic, bic, press, adj_r2, num_predictors, mse = calculate_metrics(model, X = X, y = y)
#      36 mse_cv_5 = cross_validate(X, y, k = 5)
# ---> 37 mse_cv_10 = cross_validate(X, y, k = 10)
#      38 # mse_cv_100 = cross_validate(X, y, k = 100)
#      40 results.append({
#      41     'Predictors': predictors,
#      42     'n_Predictors': num_predictors,
#    (...)
#      50     # '100-Fold_CV MSE': mse_cv_100
#      51 })
#
# Cell In[21], line 17, in cross_validate(X, y, k)
#      14 X_val, y_val = X.iloc[val_indices], y.iloc[val_indices]
#      16 #calculate mse if you train the model with the training set
# ---> 17 model = sm.OLS(y_train, X_train).fit()
#      18 predictions = model.predict(X_val)
#      19 mse = ((predictions - y_val.squeeze()) ** 2).mean()
#
# File /opt/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:336, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     331 if method == "pinv":
#     332     if not (hasattr(self, 'pinv_wexog') and
#     333             hasattr(self, 'normalized_cov_params') and
#     334             hasattr(self, 'rank')):
# --> 336         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     337         self.normalized_cov_params = np.dot(
#     338             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     340         # Cache these singular values for use later.
#
# File /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tools/tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
dataframes = []
for i in range(n):
    with open(f'models/results_df_{i}.pkl', 'rb') as f:
        data = pickle.load(f)
    #concat all the data into one dataframe
    dataframes.append(data)
results_df = pd.concat(dataframes, ignore_index=True)
results_df.to_csv('models/all_results_df.csv', index=False)
results_df
# Out:
#                                               Predictors  n_Predictors  \
# 0                                                [Wheel]             1
# 1                                            [Prod_year]             1
# 2                                     [Leather_interior]             1
# 3                                        [Engine_Volume]             1
# 4                                             [HasTurbo]             1
# ...                                                  ...           ...
# 32762  [Manufacturer, Prod_year, Category, Leather_in...            88
# 32763  [Manufacturer, Prod_year, Category, Leather_in...            88
# 32764  [Manufacturer, Prod_year, Category, Fuel_type,...            88
# 32765  [Manufacturer, Category, Leather_interior, Fue...            88
# 32766  [Manufacturer, Prod_year, Category, Leather_in...            89
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 0          0.017426  44932.145767  44943.347572  6.684511e+11  3.338478e+08
# 1          0.085955  44787.554836  44798.756641  6.231931e+11  3.105639e+08
# 2          0.016570  44933.888300  44945.090105  6.693437e+11  3.341388e+08
# 3          0.011283  44944.611106  44955.812911  6.741469e+11  3.359351e+08
# 4          0.046945  44871.139192  44882.340997  6.495586e+11  3.238181e+08
# ...             ...           ...           ...           ...           ...
# 32762      0.307411  44317.628274  44816.108593  2.329468e+20  2.250734e+08
# 32763      0.322453  44273.712290  44772.192609  6.356887e+20  2.201851e+08
# 32764      0.323788  44269.769083  44768.249402  1.410980e+20  2.197514e+08
# 32765      0.234284  44518.378779  45016.859097           inf  2.488379e+08
# 32766      0.323434  44271.767731  44775.848952  1.364124e+21  2.197513e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 0       3.341604e+08    3.340392e+08
# 1       3.110198e+08    3.112046e+08
# 2       3.347360e+08    3.345047e+08
# 3       3.367175e+08    3.366080e+08
# 4       3.242530e+08    3.242776e+08
# ...              ...             ...
# 32762   1.384365e+10    1.455920e+10
# 32763   1.385893e+10    1.476848e+10
# 32764   1.578653e+10    1.653652e+10
# 32765   3.771471e+10    3.949092e+10
# 32766   1.585317e+10    1.662179e+10
#
# [32767 rows x 9 columns]

# %% [markdown]
# ## Analysis

# %%
print('Lowest MSE')
results_df.sort_values('MSE').head(5)
# Out:
# Lowest MSE
#                                               Predictors  n_Predictors  \
# 32766  [Manufacturer, Prod_year, Category, Leather_in...            89
# 32764  [Manufacturer, Prod_year, Category, Fuel_type,...            88
# 32761  [Manufacturer, Prod_year, Category, Leather_in...            88
# 32754  [Manufacturer, Prod_year, Category, Fuel_type,...            87
# 32758  [Manufacturer, Prod_year, Category, Leather_in...            88
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 32766      0.323434  44271.767731  44775.848952  1.364124e+21  2.197513e+08
# 32764      0.323788  44269.769083  44768.249402  1.410980e+20  2.197514e+08
# 32761      0.323777  44269.801112  44768.281431  1.524720e+14  2.197549e+08
# 32754      0.324130  44267.802051  44760.681468  5.135175e+14  2.197550e+08
# 32758      0.323725  44269.954882  44768.435201  8.451237e+22  2.197718e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 32766   1.585317e+10    1.662179e+10
# 32764   1.578653e+10    1.653652e+10
# 32761   2.490515e+08    2.466119e+08
# 32754   2.489379e+08    2.464479e+08
# 32758   1.584767e+10    1.661215e+10

# %%
print('Lowest 5 fold CV MSE')
results_df.sort_values('5-Fold_CV MSE').head(5)
# Out:
# Lowest 5 fold CV MSE
#                                               Predictors  n_Predictors  \
# 28559  [Manufacturer, Prod_year, Category, Fuel_type,...            69
# 23305  [Manufacturer, Prod_year, Category, Fuel_type,...            67
# 23325  [Manufacturer, Prod_year, Category, Fuel_type,...            68
# 30879  [Manufacturer, Prod_year, Category, Leather_in...            70
# 16806  [Manufacturer, Prod_year, Category, Fuel_type,...            66
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 28559      0.324804  44248.547644  44640.610816  3.617383e+13  2.216027e+08
# 23305      0.323574  44250.260426  44631.121794  5.608619e+15  2.222366e+08
# 23325      0.324988  44247.039093  44633.501363  1.211362e+13  2.216572e+08
# 30879      0.324470  44250.500728  44648.164802  2.847906e+12  2.215975e+08
# 16806      0.323742  44248.798109  44624.058574  3.305393e+13  2.222964e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 28559   2.460270e+08    2.444512e+08
# 23305   2.461083e+08    2.445209e+08
# 23325   2.461122e+08    2.444605e+08
# 30879   2.461723e+08    2.445781e+08
# 16806   2.462039e+08    2.445568e+08

# %%
print('Lowest 10 fold CV MSE')
results_df.sort_values('10-Fold_CV MSE').head(5)
# Out:
# Lowest 10 fold CV MSE
#                                               Predictors  n_Predictors  \
# 28559  [Manufacturer, Prod_year, Category, Fuel_type,...            69
# 23325  [Manufacturer, Prod_year, Category, Fuel_type,...            68
# 28221  [Manufacturer, Prod_year, Category, Fuel_type,...            69
# 23305  [Manufacturer, Prod_year, Category, Fuel_type,...            67
# 31137  [Manufacturer, Prod_year, Category, Fuel_type,...            70
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 28559      0.324804  44248.547644  44640.610816  3.617383e+13  2.216027e+08
# 23325      0.324988  44247.039093  44633.501363  1.211362e+13  2.216572e+08
# 28221      0.326280  44244.169679  44636.232852  5.709619e+11  2.211182e+08
# 23305      0.323574  44250.260426  44631.121794  5.608619e+15  2.222366e+08
# 31137      0.326012  44245.928356  44643.592430  1.027410e+12  2.210915e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 28559   2.460270e+08    2.444512e+08
# 23325   2.461122e+08    2.444605e+08
# 28221   2.462582e+08    2.444868e+08
# 23305   2.461083e+08    2.445209e+08
# 31137   2.462350e+08    2.445535e+08

# %%
print('Lowest AIC')
results_df.sort_values('AIC').head(5)
# Out:
# Lowest AIC
#                                               Predictors  n_Predictors  \
# 28221  [Manufacturer, Prod_year, Category, Fuel_type,...            69
# 31137  [Manufacturer, Prod_year, Category, Fuel_type,...            70
# 31142  [Manufacturer, Prod_year, Category, Fuel_type,...            70
# 30886  [Manufacturer, Prod_year, Category, Leather_in...            70
# 23325  [Manufacturer, Prod_year, Category, Fuel_type,...            68
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 28221      0.326280  44244.169679  44636.232852  5.709619e+11  2.211182e+08
# 31137      0.326012  44245.928356  44643.592430  1.027410e+12  2.210915e+08
# 31142      0.325936  44246.155729  44643.819804  1.666442e+16  2.211166e+08
# 30886      0.325933  44246.164280  44643.828354  2.336561e+13  2.211176e+08
# 23325      0.324988  44247.039093  44633.501363  1.211362e+13  2.216572e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 28221   2.462582e+08    2.444868e+08
# 31137   2.462350e+08    2.445535e+08
# 31142   1.472538e+10    1.612762e+10
# 30886   2.463565e+08    2.446656e+08
# 23325   2.461122e+08    2.444605e+08

# %%
print('Lowest BIC')
results_df.sort_values('BIC').head(5)
# Out:
# Lowest BIC
#                                               Predictors  n_Predictors  \
# 7694   [Prod_year, Fuel_type, Engine_Volume, HasTurbo...            12
# 14161  [Prod_year, Fuel_type, Engine_Volume, HasTurbo...            13
# 7980   [Prod_year, Fuel_type, HasTurbo, Cylinders, Ge...            12
# 14158  [Prod_year, Fuel_type, Engine_Volume, HasTurbo...            13
# 14162  [Prod_year, Fuel_type, HasTurbo, Cylinders, Ge...            13
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 7694       0.254162  44391.771257  44464.582989  5.128801e+11  2.520174e+08
# 14161      0.255234  44389.886018  44468.298652  5.121325e+11  2.515283e+08
# 7980       0.252567  44396.041549  44468.853281  5.140421e+11  2.525560e+08
# 14158      0.254915  44390.742400  44469.155034  5.135274e+11  2.516360e+08
# 14162      0.254441  44392.015175  44470.427809  5.127143e+11  2.517962e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 7694    2.544981e+08    2.557167e+08
# 14161   2.541019e+08    2.555276e+08
# 7980    2.551993e+08    2.563399e+08
# 14158   2.549607e+08    2.558011e+08
# 14162   2.545187e+08    2.558312e+08

# %%
print('Highest Adjusted R^2	')
results_df.sort_values('Adjusted R^2', ascending=False).head(5)
# Out:
# Highest Adjusted R^2
#                                               Predictors  n_Predictors  \
# 28221  [Manufacturer, Prod_year, Category, Fuel_type,...            69
# 31137  [Manufacturer, Prod_year, Category, Fuel_type,...            70
# 31142  [Manufacturer, Prod_year, Category, Fuel_type,...            70
# 30886  [Manufacturer, Prod_year, Category, Leather_in...            70
# 31143  [Manufacturer, Prod_year, Category, Fuel_type,...            71
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 28221      0.326280  44244.169679  44636.232852  5.709619e+11  2.211182e+08
# 31137      0.326012  44245.928356  44643.592430  1.027410e+12  2.210915e+08
# 31142      0.325936  44246.155729  44643.819804  1.666442e+16  2.211166e+08
# 30886      0.325933  44246.164280  44643.828354  2.336561e+13  2.211176e+08
# 31143      0.325734  44247.718414  44650.983391  4.302740e+14  2.210683e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 28221   2.462582e+08    2.444868e+08
# 31137   2.462350e+08    2.445535e+08
# 31142   1.472538e+10    1.612762e+10
# 30886   2.463565e+08    2.446656e+08
# 31143   2.469552e+08    2.450436e+08

# %%
print('Lowest Press')
results_df.sort_values('PRESS').head(5)
# Out:
# Lowest Press
#                                               Predictors  n_Predictors  \
# 28914  [Manufacturer, Prod_year, Leather_interior, Ha...            71
# 10320  [Manufacturer, Prod_year, Category, Fuel_type,...            65
# 28868  [Manufacturer, Prod_year, Leather_interior, Fu...            62
# 26248  [Prod_year, Category, Fuel_type, HasTurbo, Cyl...            24
# 26259  [Prod_year, Category, Fuel_type, Engine_Volume...            24
#
#        Adjusted R^2           AIC           BIC         PRESS           MSE  \
# 28914      0.288349  44355.644436  44758.909413  5.003152e+11  2.333255e+08
# 10320      0.308728  44291.749380  44661.408942  5.007999e+11  2.273492e+08
# 28868      0.308613  44289.180565  44642.037420  5.012719e+11  2.277396e+08
# 26248      0.271717  44356.016834  44496.039395  5.035307e+11  2.445992e+08
# 26259      0.271727  44355.989279  44496.011840  5.036665e+11  2.445958e+08
#
#        5-Fold_CV MSE  10-Fold_CV MSE
# 28914   2.573204e+08    2.554305e+08
# 10320   2.521758e+08    2.498940e+08
# 28868   2.497033e+08    2.482216e+08
# 26248   2.497604e+08    2.515128e+08
# 26259   2.498719e+08    2.515708e+08
