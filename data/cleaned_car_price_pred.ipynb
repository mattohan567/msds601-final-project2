# %%
import pandas as pd
import numpy as np
import string
import re

# %%
df = pd.read_csv('../Data/car_price_prediction.csv')
df.head(25)
# Out:
#           ID  Price  Levy   Manufacturer     Model  Prod. year     Category  \
# 0   45654403  13328  1399          LEXUS    RX 450        2010         Jeep
# 1   44731507  16621  1018      CHEVROLET   Equinox        2011         Jeep
# 2   45774419   8467     -          HONDA       FIT        2006    Hatchback
# 3   45769185   3607   862           FORD    Escape        2011         Jeep
# 4   45809263  11726   446          HONDA       FIT        2014    Hatchback
# 5   45802912  39493   891        HYUNDAI  Santa FE        2016         Jeep
# 6   45656768   1803   761         TOYOTA     Prius        2010    Hatchback
# 7   45816158    549   751        HYUNDAI    Sonata        2013        Sedan
# 8   45641395   1098   394         TOYOTA     Camry        2014        Sedan
# 9   45756839  26657     -          LEXUS    RX 350        2007         Jeep
# 10  45621750    941  1053  MERCEDES-BENZ     E 350        2014        Sedan
# 11  45814819   8781     -           FORD   Transit        1999     Microbus
# 12  45815568   3000     -           OPEL    Vectra        1997  Goods wagon
# 13  45661288   1019  1055          LEXUS    RX 450        2013         Jeep
# 14  45732604  59464   891        HYUNDAI  Santa FE        2016         Jeep
# 15  45465200    549  1079         TOYOTA       CHR        2018         Jeep
# 16  45772281   7683   810        HYUNDAI   Elantra        2016        Sedan
# 17  45797221  28382   810        HYUNDAI   Elantra        2016        Sedan
# 18  45772104    549  2386        HYUNDAI    Sonata        2006        Sedan
# 19  45653306    941  1850          LEXUS    RX 400        2008         Jeep
# 20  45801686  18826   531        HYUNDAI   Elantra        2012        Sedan
# 21  45168471  20698   586         TOYOTA     Prius        2012        Sedan
# 22  45751951  17562  1249         TOYOTA     Camry        2017        Sedan
# 23  45814106   7840     -           FORD   Transit        2001     Microbus
# 24  45813492   4704     -           OPEL    Vectra        1995        Sedan
#
#    Leather interior       Fuel type Engine volume    Mileage  Cylinders  \
# 0               Yes          Hybrid           3.5  186005 km        6.0
# 1                No          Petrol             3  192000 km        6.0
# 2                No          Petrol           1.3  200000 km        4.0
# 3               Yes          Hybrid           2.5  168966 km        4.0
# 4               Yes          Petrol           1.3   91901 km        4.0
# 5               Yes          Diesel             2  160931 km        4.0
# 6               Yes          Hybrid           1.8  258909 km        4.0
# 7               Yes          Petrol           2.4  216118 km        4.0
# 8               Yes          Hybrid           2.5  398069 km        4.0
# 9               Yes          Petrol           3.5  128500 km        6.0
# 10              Yes          Diesel           3.5  184467 km        6.0
# 11               No             CNG             4       0 km        8.0
# 12               No             CNG           1.6  350000 km        4.0
# 13              Yes          Hybrid           3.5  138038 km        6.0
# 14              Yes          Diesel             2   76000 km        4.0
# 15              Yes          Petrol             2   74146 km        4.0
# 16              Yes          Petrol           1.8  121840 km        4.0
# 17              Yes          Petrol           1.8   54317 km        4.0
# 18              Yes          Petrol           3.3  295059 km        6.0
# 19              Yes          Hybrid           3.5  364523 km        6.0
# 20              Yes          Petrol           1.6  112645 km        4.0
# 21              Yes  Plug-in Hybrid           1.8  187000 km        4.0
# 22              Yes          Petrol           2.5   39709 km        4.0
# 23               No          Diesel     2.0 Turbo  230000 km        4.0
# 24               No          Petrol           1.8       0 km        4.0
#
#    Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0      Automatic          4x4  04-May        Left wheel  Silver       12
# 1      Tiptronic          4x4  04-May        Left wheel   Black        8
# 2       Variator        Front  04-May  Right-hand drive   Black        2
# 3      Automatic          4x4  04-May        Left wheel   White        0
# 4      Automatic        Front  04-May        Left wheel  Silver        4
# 5      Automatic        Front  04-May        Left wheel   White        4
# 6      Automatic        Front  04-May        Left wheel   White       12
# 7      Automatic        Front  04-May        Left wheel    Grey       12
# 8      Automatic        Front  04-May        Left wheel   Black       12
# 9      Automatic          4x4  04-May        Left wheel  Silver       12
# 10     Automatic         Rear  04-May        Left wheel   White       12
# 11        Manual         Rear  02-Mar        Left wheel    Blue        0
# 12        Manual        Front  04-May        Left wheel   White        4
# 13     Automatic        Front  04-May        Left wheel   White       12
# 14     Automatic        Front  04-May        Left wheel   White        4
# 15     Automatic        Front  04-May        Left wheel   White       12
# 16     Automatic        Front  04-May        Left wheel    Blue       12
# 17     Automatic        Front  04-May        Left wheel   White        4
# 18     Automatic         Rear  04-May        Left wheel    Blue       12
# 19     Automatic          4x4  04-May        Left wheel   Black       12
# 20     Automatic        Front  04-May        Left wheel  Silver        4
# 21     Automatic        Front  04-May        Left wheel   White       12
# 22     Automatic        Front  04-May        Left wheel   Black       12
# 23        Manual        Front  02-Mar        Left wheel   White        0
# 24     Automatic        Front  04-May        Left wheel   Green        4

# %% [markdown]
# <h1>Data Cleaning Rules</h1>
#
# 1. Remove columns: ID, Levy, Model
# 2. Convert 'engine volume' mixed type column into: engine volume column and HasTurbo column
# 3. Change mileage into type int, remove the unit 'km' (just change the column title)
# 4. Remove all rows that has any null data: X rows removed (Y% of all rows)

# %%
#1 Remove the 3 columns

df_rem = df.copy()
del df_rem['ID']
del df_rem['Levy']
del df_rem['Model']
df_rem.head()
# Out:
#    Price Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  13328        LEXUS        2010       Jeep              Yes    Hybrid
# 1  16621    CHEVROLET        2011       Jeep               No    Petrol
# 2   8467        HONDA        2006  Hatchback               No    Petrol
# 3   3607         FORD        2011       Jeep              Yes    Hybrid
# 4  11726        HONDA        2014  Hatchback              Yes    Petrol
#
#   Engine volume    Mileage  Cylinders Gear box type Drive wheels   Doors  \
# 0           3.5  186005 km        6.0     Automatic          4x4  04-May
# 1             3  192000 km        6.0     Tiptronic          4x4  04-May
# 2           1.3  200000 km        4.0      Variator        Front  04-May
# 3           2.5  168966 km        4.0     Automatic          4x4  04-May
# 4           1.3   91901 km        4.0     Automatic        Front  04-May
#
#               Wheel   Color  Airbags
# 0        Left wheel  Silver       12
# 1        Left wheel   Black        8
# 2  Right-hand drive   Black        2
# 3        Left wheel   White        0
# 4        Left wheel  Silver        4

# %%
#2 Convert 'Engine volume' to 'Engine Volume' and 'HasTurbo'

full_eng = df_rem['Engine volume']
split_eng = []
for i in range(len(full_eng)):
    split_eng.append(list(np.zeros(2).astype(int)))

for i in range(len(split_eng)):
    for j in range(len(full_eng[i].split())):
        split_eng[i][j] = full_eng[i].split()[j]

# %%
new_columns_df = pd.DataFrame(split_eng, columns=['Engine Volume', 'HasTurbo'])

engine_volume_pos = df_rem.columns.get_loc('Engine volume')

df_split_engine = pd.concat([df_rem.iloc[:, :engine_volume_pos], new_columns_df, df_rem.iloc[:, engine_volume_pos+1:]], axis=1)
df_split_engine['Engine Volume'] = df_split_engine['Engine Volume'].astype(float)

# %%
has_turbo = df_split_engine['HasTurbo']
turbo_bool = [has_turbo[i]=='Turbo' for i in range(len(has_turbo))]
df_split_engine['HasTurbo'] = turbo_bool
df_split_engine.head(25)
# Out:
#     Price   Manufacturer  Prod. year     Category Leather interior  \
# 0   13328          LEXUS        2010         Jeep              Yes
# 1   16621      CHEVROLET        2011         Jeep               No
# 2    8467          HONDA        2006    Hatchback               No
# 3    3607           FORD        2011         Jeep              Yes
# 4   11726          HONDA        2014    Hatchback              Yes
# 5   39493        HYUNDAI        2016         Jeep              Yes
# 6    1803         TOYOTA        2010    Hatchback              Yes
# 7     549        HYUNDAI        2013        Sedan              Yes
# 8    1098         TOYOTA        2014        Sedan              Yes
# 9   26657          LEXUS        2007         Jeep              Yes
# 10    941  MERCEDES-BENZ        2014        Sedan              Yes
# 11   8781           FORD        1999     Microbus               No
# 12   3000           OPEL        1997  Goods wagon               No
# 13   1019          LEXUS        2013         Jeep              Yes
# 14  59464        HYUNDAI        2016         Jeep              Yes
# 15    549         TOYOTA        2018         Jeep              Yes
# 16   7683        HYUNDAI        2016        Sedan              Yes
# 17  28382        HYUNDAI        2016        Sedan              Yes
# 18    549        HYUNDAI        2006        Sedan              Yes
# 19    941          LEXUS        2008         Jeep              Yes
# 20  18826        HYUNDAI        2012        Sedan              Yes
# 21  20698         TOYOTA        2012        Sedan              Yes
# 22  17562         TOYOTA        2017        Sedan              Yes
# 23   7840           FORD        2001     Microbus               No
# 24   4704           OPEL        1995        Sedan               No
#
#          Fuel type  Engine Volume  HasTurbo    Mileage  Cylinders  \
# 0           Hybrid            3.5     False  186005 km        6.0
# 1           Petrol            3.0     False  192000 km        6.0
# 2           Petrol            1.3     False  200000 km        4.0
# 3           Hybrid            2.5     False  168966 km        4.0
# 4           Petrol            1.3     False   91901 km        4.0
# 5           Diesel            2.0     False  160931 km        4.0
# 6           Hybrid            1.8     False  258909 km        4.0
# 7           Petrol            2.4     False  216118 km        4.0
# 8           Hybrid            2.5     False  398069 km        4.0
# 9           Petrol            3.5     False  128500 km        6.0
# 10          Diesel            3.5     False  184467 km        6.0
# 11             CNG            4.0     False       0 km        8.0
# 12             CNG            1.6     False  350000 km        4.0
# 13          Hybrid            3.5     False  138038 km        6.0
# 14          Diesel            2.0     False   76000 km        4.0
# 15          Petrol            2.0     False   74146 km        4.0
# 16          Petrol            1.8     False  121840 km        4.0
# 17          Petrol            1.8     False   54317 km        4.0
# 18          Petrol            3.3     False  295059 km        6.0
# 19          Hybrid            3.5     False  364523 km        6.0
# 20          Petrol            1.6     False  112645 km        4.0
# 21  Plug-in Hybrid            1.8     False  187000 km        4.0
# 22          Petrol            2.5     False   39709 km        4.0
# 23          Diesel            2.0      True  230000 km        4.0
# 24          Petrol            1.8     False       0 km        4.0
#
#    Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0      Automatic          4x4  04-May        Left wheel  Silver       12
# 1      Tiptronic          4x4  04-May        Left wheel   Black        8
# 2       Variator        Front  04-May  Right-hand drive   Black        2
# 3      Automatic          4x4  04-May        Left wheel   White        0
# 4      Automatic        Front  04-May        Left wheel  Silver        4
# 5      Automatic        Front  04-May        Left wheel   White        4
# 6      Automatic        Front  04-May        Left wheel   White       12
# 7      Automatic        Front  04-May        Left wheel    Grey       12
# 8      Automatic        Front  04-May        Left wheel   Black       12
# 9      Automatic          4x4  04-May        Left wheel  Silver       12
# 10     Automatic         Rear  04-May        Left wheel   White       12
# 11        Manual         Rear  02-Mar        Left wheel    Blue        0
# 12        Manual        Front  04-May        Left wheel   White        4
# 13     Automatic        Front  04-May        Left wheel   White       12
# 14     Automatic        Front  04-May        Left wheel   White        4
# 15     Automatic        Front  04-May        Left wheel   White       12
# 16     Automatic        Front  04-May        Left wheel    Blue       12
# 17     Automatic        Front  04-May        Left wheel   White        4
# 18     Automatic         Rear  04-May        Left wheel    Blue       12
# 19     Automatic          4x4  04-May        Left wheel   Black       12
# 20     Automatic        Front  04-May        Left wheel  Silver        4
# 21     Automatic        Front  04-May        Left wheel   White       12
# 22     Automatic        Front  04-May        Left wheel   Black       12
# 23        Manual        Front  02-Mar        Left wheel   White        0
# 24     Automatic        Front  04-May        Left wheel   Green        4

# %%
#3 Change column type of 'Mileage' to int and remove km

# First, check that the only units used is km, and not other units such as miles
split_mileage = df['Mileage'].str.split(' ', expand=True)
    
k = (split_mileage[1] != 'km').sum()
k
# Out:
# 0

# %%
# We know for sure that all units are in km. Time to remove it.
df_int_mi = df_split_engine.copy()
df_int_mi['Mileage'] = df_int_mi['Mileage'].str.replace(' km', '', regex=False).astype(int)
df_int_mi
# Out:
#        Price   Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0      13328          LEXUS        2010       Jeep              Yes    Hybrid
# 1      16621      CHEVROLET        2011       Jeep               No    Petrol
# 2       8467          HONDA        2006  Hatchback               No    Petrol
# 3       3607           FORD        2011       Jeep              Yes    Hybrid
# 4      11726          HONDA        2014  Hatchback              Yes    Petrol
# ...      ...            ...         ...        ...              ...       ...
# 19232   8467  MERCEDES-BENZ        1999      Coupe              Yes       CNG
# 19233  15681        HYUNDAI        2011      Sedan              Yes    Petrol
# 19234  26108        HYUNDAI        2010       Jeep              Yes    Diesel
# 19235   5331      CHEVROLET        2007       Jeep              Yes    Diesel
# 19236    470        HYUNDAI        2012      Sedan              Yes    Hybrid
#
#        Engine Volume  HasTurbo  Mileage  Cylinders Gear box type Drive wheels  \
# 0                3.5     False   186005        6.0     Automatic          4x4
# 1                3.0     False   192000        6.0     Tiptronic          4x4
# 2                1.3     False   200000        4.0      Variator        Front
# 3                2.5     False   168966        4.0     Automatic          4x4
# 4                1.3     False    91901        4.0     Automatic        Front
# ...              ...       ...      ...        ...           ...          ...
# 19232            2.0      True   300000        4.0        Manual         Rear
# 19233            2.4     False   161600        4.0     Tiptronic        Front
# 19234            2.0     False   116365        4.0     Automatic        Front
# 19235            2.0     False    51258        4.0     Automatic        Front
# 19236            2.4     False   186923        4.0     Automatic        Front
#
#         Doors             Wheel   Color  Airbags
# 0      04-May        Left wheel  Silver       12
# 1      04-May        Left wheel   Black        8
# 2      04-May  Right-hand drive   Black        2
# 3      04-May        Left wheel   White        0
# 4      04-May        Left wheel  Silver        4
# ...       ...               ...     ...      ...
# 19232  02-Mar        Left wheel  Silver        5
# 19233  04-May        Left wheel     Red        8
# 19234  04-May        Left wheel    Grey        4
# 19235  04-May        Left wheel   Black        4
# 19236  04-May        Left wheel   White       12
#
# [19237 rows x 16 columns]

# %%
#4 Remove null data, it seems we started with a full set!
df_cleaned = df_int_mi.dropna()
df_cleaned
# Out:
#        Price   Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0      13328          LEXUS        2010       Jeep              Yes    Hybrid
# 1      16621      CHEVROLET        2011       Jeep               No    Petrol
# 2       8467          HONDA        2006  Hatchback               No    Petrol
# 3       3607           FORD        2011       Jeep              Yes    Hybrid
# 4      11726          HONDA        2014  Hatchback              Yes    Petrol
# ...      ...            ...         ...        ...              ...       ...
# 19232   8467  MERCEDES-BENZ        1999      Coupe              Yes       CNG
# 19233  15681        HYUNDAI        2011      Sedan              Yes    Petrol
# 19234  26108        HYUNDAI        2010       Jeep              Yes    Diesel
# 19235   5331      CHEVROLET        2007       Jeep              Yes    Diesel
# 19236    470        HYUNDAI        2012      Sedan              Yes    Hybrid
#
#        Engine Volume  HasTurbo  Mileage  Cylinders Gear box type Drive wheels  \
# 0                3.5     False   186005        6.0     Automatic          4x4
# 1                3.0     False   192000        6.0     Tiptronic          4x4
# 2                1.3     False   200000        4.0      Variator        Front
# 3                2.5     False   168966        4.0     Automatic          4x4
# 4                1.3     False    91901        4.0     Automatic        Front
# ...              ...       ...      ...        ...           ...          ...
# 19232            2.0      True   300000        4.0        Manual         Rear
# 19233            2.4     False   161600        4.0     Tiptronic        Front
# 19234            2.0     False   116365        4.0     Automatic        Front
# 19235            2.0     False    51258        4.0     Automatic        Front
# 19236            2.4     False   186923        4.0     Automatic        Front
#
#         Doors             Wheel   Color  Airbags
# 0      04-May        Left wheel  Silver       12
# 1      04-May        Left wheel   Black        8
# 2      04-May  Right-hand drive   Black        2
# 3      04-May        Left wheel   White        0
# 4      04-May        Left wheel  Silver        4
# ...       ...               ...     ...      ...
# 19232  02-Mar        Left wheel  Silver        5
# 19233  04-May        Left wheel     Red        8
# 19234  04-May        Left wheel    Grey        4
# 19235  04-May        Left wheel   Black        4
# 19236  04-May        Left wheel   White       12
#
# [19237 rows x 16 columns]

# %%
# Save df_cleaned to a new file
df_cleaned.to_csv('cleaned_car_price_prediction.csv', index=False)
